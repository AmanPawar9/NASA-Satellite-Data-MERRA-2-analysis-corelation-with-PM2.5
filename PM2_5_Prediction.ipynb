# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(30,30))
#plot heat map
g=sns.heatmap(df[top_corr_features].corr(),annot=True,cmap="RdYlGn")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/PM2.5
# Out:
# /content/drive/MyDrive/PM2.5

# %%
# !ls
# Out:
# aerosol.csv  aod.csv  delhi_hourly_pm25_2006-2018.csv  surfaceflux.csv

# %%
import pandas as pd

# %%
df=pd.read_csv('surfaceflux.csv')
df.shape
df.head()
# Out:
#    Unnamed: 0                 time     lon  ...  TOTANGSTR  TOTEXTTAU  TOTSCATAU
# 0           0  2000-01-03 00:30:00  76.875  ...   1.682776   0.093921   0.075047
# 1           1  2000-01-03 00:30:00  77.500  ...   1.719885   0.099689   0.080846
# 2           2  2000-01-03 01:30:00  76.875  ...   1.677330   0.093353   0.074441
# 3           3  2000-01-03 01:30:00  77.500  ...   1.715904   0.099365   0.080423
# 4           4  2000-01-03 02:30:00  76.875  ...   1.674807   0.093097   0.074177
#
# [5 rows x 54 columns]

# %%
df.drop(['time','lon','lat','BCANGSTR',	'BCCMASS',	'BCEXTTAU',	'BCFLUXU',	'BCFLUXV',	'BCSCATAU', 'DMSCMASS',	'DMSSMASS','DUANGSTR',	'DUCMASS',	'DUCMASS25',	'DUEXTT25',	'DUEXTTAU',	'DUFLUXU',	'DUFLUXV',	'DUSCAT25',	'DUSCATAU',	'DUSMASS','OCANGSTR',	'OCCMASS',	'OCEXTTAU',	'OCFLUXU',	'OCFLUXV',	'OCSCATAU', 'SO2CMASS',	'SO2SMASS',	'SO4CMASS','SSANGSTR',	'SSCMASS',	'SSCMASS25',	'SSEXTT25',	'SSEXTTAU',	'SSFLUXU',	'SSFLUXV',	'SSSCAT25',	'SSSCATAU',	'SSSMASS', 'SUANGSTR',	'SUEXTTAU',	'SUFLUXU',	'SUFLUXV',	'SUSCATAU',	'TOTANGSTR',	'TOTEXTTAU',	'TOTSCATAU'], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    Unnamed: 0       BCSMASS  ...      SO4SMASS     SSSMASS25
# 0           0  5.557018e-09  ...  4.824727e-09  3.507329e-11
# 1           1  5.309635e-09  ...  6.267186e-09  3.275692e-11
# 2           2  5.687994e-09  ...  4.733737e-09  3.528649e-11
# 3           3  5.560664e-09  ...  6.167101e-09  3.304117e-11
# 4           4  5.766215e-09  ...  4.668278e-09  3.541242e-11
#
# [5 rows x 6 columns]

# %%
df1=pd.read_csv('aerosol.csv')
df1.shape
df1.head()
# Out:
#    Unnamed: 0                 time     lon  ...      VLML       Z0H       Z0M
# 0           0  2000-01-04 00:30:00  76.875  ... -1.784813  0.049398  0.049398
# 1           1  2000-01-04 00:30:00  77.500  ... -2.371239  0.048574  0.048574
# 2           2  2000-01-04 01:30:00  76.875  ... -1.153747  0.049413  0.049413
# 3           3  2000-01-04 01:30:00  77.500  ... -1.863220  0.048604  0.048604
# 4           4  2000-01-04 02:30:00  76.875  ... -0.578119  0.049443  0.049443
#
# [5 rows x 50 columns]

# %%
df1.drop(['time','lon','lat','BSTAR',	'CDH',	'CDM',	'CDQ',	'CN',	'DISPH',	'EFLUX',	'EVAP',	'FRCAN',	'FRCCN',	'FRCLS',	'FRSEAICE',	'GHTSKIN',	'HFLUX',	'HLML',	'NIRDF',	'NIRDR',
          'PGENTOT',	'PRECANV',	'PRECCON',	'PRECLSC',	'PRECSNO',	'PRECTOT',	'PRECTOTCORR',	'PREVTOT',	'QSH',	'QSTAR',	'RHOA','RISFC',
           'SPEEDMAX',	'TAUGWX',	'TAUGWY',	'TAUX',	'TAUY',	'TCZPBL', 'TSH',	'TSTAR',	'ULML',	'USTAR',	'VLML',	'Z0H',	'Z0M'	], axis = 1, inplace = True)

# %%
df1.head()
# Out:
#    Unnamed: 0       PBLH      QLML     SPEED       TLML
# 0           0  62.871986  0.001942  2.749119  284.26566
# 1           1  62.856360  0.001893  3.306736  284.17972
# 2           2  62.814087  0.001951  2.615660  283.95685
# 3           3  62.767212  0.001904  3.240660  283.76935
# 4           4  62.776054  0.001960  2.650817  283.80762

# %%
df2=pd.read_csv('aod.csv')
df2.shape
df2.head()
# Out:
#    Unnamed: 0  latitude  ...  time_of_measurement  viewing_zenith_angle
# 0           0     28.25  ...                  NaN                   NaN
# 1           1     28.25  ...                  NaN                   NaN
# 2           2     28.25  ...                  NaN                   NaN
# 3           3     28.25  ...                  NaN                   NaN
# 4           4     28.25  ...                  NaN                   NaN
#
# [5 rows x 53 columns]

# %%
df2.drop(["latitude"	,"longitude",	"land_bands","ocean_bands","aerosol_optical_thickness_550_count_land_ocean","aerosol_optical_thickness_550_count_ocean",
  "aerosol_optical_thickness_550_land","aerosol_optical_thickness_550_land_ocean","aerosol_optical_thickness_550_ocean","aerosol_optical_thickness_550_stddev_land",
  "aerosol_optical_thickness_550_stddev_land_ocean","aerosol_optical_thickness_550_stddev_ocean","aerosol_optical_thickness_count_ocean","aerosol_optical_thickness_land",
  "aerosol_optical_thickness_ocean","aerosol_optical_thickness_stddev_land","aerosol_optical_thickness_stddev_ocean","angstrom_exponent_count_land",
  "angstrom_exponent_count_land_ocean","angstrom_exponent_count_ocean","angstrom_exponent_land","angstrom_exponent_land_ocean","angstrom_exponent_ocean",
  "angstrom_exponent_stddev_land","angstrom_exponent_stddev_land_ocean","angstrom_exponent_stddev_ocean","diagnostics_aerosol_optical_thickness_550_maximum_land",
  "diagnostics_aerosol_optical_thickness_550_maximum_land_ocean","diagnostics_aerosol_optical_thickness_550_maximum_ocean","diagnostics_aerosol_optical_thickness_550_minimum_land",
  "diagnostics_aerosol_optical_thickness_550_minimum_land_ocean","diagnostics_aerosol_optical_thickness_550_minimum_ocean","diagnostics_aerosol_optical_thickness_maximum_land",
  "diagnostics_aerosol_optical_thickness_maximum_ocean","diagnostics_aerosol_optical_thickness_minimum_land","diagnostics_aerosol_optical_thickness_minimum_ocean",
  "diagnostics_angstrom_exponent_maximum_land","diagnostics_angstrom_exponent_maximum_land_ocean","diagnostics_angstrom_exponent_maximum_ocean",
  "diagnostics_angstrom_exponent_minimum_land","diagnostics_angstrom_exponent_minimum_land_ocean","diagnostics_angstrom_exponent_minimum_ocean",
  "diagnostics_fine_mode_volume_fraction_ocean","diagnostics_fine_mode_volume_fraction_stddev_ocean","diagnostics_wind_speed","relative_azimuth_angle",
  "scattering_angle",	"solar_zenith_angle",	"time_of_measurement",	"viewing_zenith_angle"],axis = 1, inplace = True)

# %%
df2.head()
# Out:
#    Unnamed: 0  ...  aerosol_optical_thickness_count_land
# 0           0  ...                                   0.0
# 1           1  ...                                   0.0
# 2           2  ...                                   0.0
# 3           3  ...                                   0.0
# 4           4  ...                                   0.0
#
# [5 rows x 3 columns]

# %%
df3=pd.read_csv('delhi_hourly_pm25_2006-2018.csv')
df3.shape
df3.head()
# Out:
#   station           city  dd-mmm-yyyy  hh:mm  year  month  day  hour  value
# 0     ITO   Delhi - CPCB  05-Sep-2006  14:00  2006      9    5    15   45.2
# 1     ITO   Delhi - CPCB  05-Sep-2006  14:15  2006      9    5    15   44.7
# 2     ITO   Delhi - CPCB  05-Sep-2006  14:30  2006      9    5    15   44.6
# 3     ITO   Delhi - CPCB  05-Sep-2006  14:45  2006      9    5    15   44.6
# 4     ITO   Delhi - CPCB  05-Sep-2006  15:00  2006      9    5    16   44.6

# %%
df3.drop(["station",	"city",	"dd-mmm-yyyy",	"hh:mm",	"year",	"month",	"day",	"hour"], axis = 1, inplace = True)

# %%
df3.head()
# Out:
#    value
# 0   45.2
# 1   44.7
# 2   44.6
# 3   44.6
# 4   44.6

# %%
res2 = pd.concat([df, df1, df2, df3], axis=1, join='inner')
 
res2
# Out:
#        Unnamed: 0       BCSMASS  ...  aerosol_optical_thickness_count_land  value
# 0               0  5.557018e-09  ...                                   0.0   45.2
# 1               1  5.309635e-09  ...                                   0.0   44.7
# 2               2  5.687994e-09  ...                                   0.0   44.6
# 3               3  5.560664e-09  ...                                   0.0   44.6
# 4               4  5.766215e-09  ...                                   0.0   44.6
# ...           ...           ...  ...                                   ...    ...
# 94549       94549  2.268280e-09  ...                                   0.0   66.8
# 94550       94550  3.679816e-09  ...                                   0.0   73.9
# 94551       94551  2.252818e-09  ...                                   0.0   74.0
# 94552       94552  3.850801e-09  ...                                   0.0   71.6
# ...

# %%
res2 .drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
res2 .head()
# Out:
#         BCSMASS     DUSMASS25  ...  aerosol_optical_thickness_count_land  value
# 0  5.557018e-09  2.348315e-09  ...                                   0.0   45.2
# 1  5.309635e-09  2.188244e-09  ...                                   0.0   44.7
# 2  5.687994e-09  2.366505e-09  ...                                   0.0   44.6
# 3  5.560664e-09  2.207344e-09  ...                                   0.0   44.6
# 4  5.766215e-09  2.381057e-09  ...                                   0.0   44.6
#
# [5 rows x 12 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.heatmap(res2 .isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
res2 .shape
# Out:
# (94554, 12)

# %%
X=res2 .iloc[:,:-1] ## independent features
y=res2 .iloc[:,-1] ## dependent features

# %%
sns.pairplot(res2 )

# %%
df.corr()
# Out:
#             Unnamed: 0   BCSMASS  DUSMASS25   OCSMASS  SO4SMASS  SSSMASS25
# Unnamed: 0    1.000000  0.055227  -0.042417  0.060679  0.157575  -0.045575
# BCSMASS       0.055227  1.000000  -0.119450  0.982220  0.842281  -0.239944
# DUSMASS25    -0.042417 -0.119450   1.000000 -0.093267 -0.094786   0.646768
# OCSMASS       0.060679  0.982220  -0.093267  1.000000  0.845748  -0.237859
# SO4SMASS      0.157575  0.842281  -0.094786  0.845748  1.000000  -0.181724
# SSSMASS25    -0.045575 -0.239944   0.646768 -0.237859 -0.181724   1.000000

# %%
import seaborn as sns
#get correlations of each features in dataset
corrmat = res2 .corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g=sns.heatmap(res2 [top_corr_features].corr(),annot=True,cmap="RdYlGn")
